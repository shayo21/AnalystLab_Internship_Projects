# %% [markdown]
# # IMPORTATION OF LIBRARIES INTO PYTHON ENVIRONMENT

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Set visualization styles
sns.set_theme(style="whitegrid")

# %% [markdown]
# ## TASK 1: DATASET UNDERSTANDING

# %% [markdown]
# Understanding the full concept of a data is the primary role for a Data Analyst when analyzing a dataset. Some functions such as df.head(), df.shape(), and df.info(), were used to get more information about both dataset and the tasks were carried out in response to the information given by the function.

# %%
netflix_df = pd.read_csv('netflix_titles.csv')
retail_df = pd.read_csv('OnlineRetail.csv', encoding='ISO-8859-1')

# %%
# df.head() is used to get first five rows of a dataset
netflix_df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# Get the shape of Netflix Titles dataset 
print("Netflix Data Shape:", netflix_df.shape)
# Out:
# Netflix Data Shape: (8807, 12)

# %%
# Get the shape of Online Retail dataset 
print("Online Retail Data Shape:", retail_df.shape)
# Out:
# Online Retail Data Shape: (541909, 8)

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
retail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# ### DATASET DESCRIPTION FOR ANALYSIS

# %% [markdown]
# 1.**E-commerce Transaction Dataset (OnlineRetail.csv)**
# This is a dataset containing  all the transactions occurring between December 1, 2010, and December 9, 2011, for a UK-based and registered non-store online retail company. The company mainly sells unique all-occasion gifts, and many of its customers are whoLesalers. It tracks every row that represent a single product purchased within an order. It also tracks the invoice number, the specific product (stock code and description), the quantity purchased, the date/time of the transaction, the unit price, the unique customer ID, and the customer's country.
#
# 2. **Netflix Movies & TV Shows Dataset (netflix_titles.csv)**
#
# This dataset consists of a comprehensive catalog of all the movies and TV shows available on the Netflix platform (as of late 2021), which indicate row represented in a single piece of content (a movie or a TV series). It details the content's unique ID, type (Movie or TV Show), title, director, cast members, country of production, the exact date it was added to the platform, original release year, age rating (e.g., TV-MA, PG-13), duration (in minutes or seasons), genres/categories, and a short text synopsis.

# %% [markdown]
# # Identifying important features in the dataset
#
# During the analysis, some features were identified from the Netflix and Online Retail dataset. Numerical column for Netflix is release_year, while that of Retail is Quantity and unit price. Categorical columns are Country, type, and rating for Netflix.
#
# Primary keys are unique keys in a dataset that helps to identify every single record or row. The primary keys for this analysis are show_id for Netflix, Invoice No and Stock Code for Retail.

# %% [markdown]
# ## TASK 2: DATA CLEANING (using .py file)

# %% [markdown]
# %%writefile preprocessing.py
#
# import pandas as pd
#
# def clean_data(df):
#     df = df.drop_duplicates()
#     df = df.dropna()
#     return df

# %% [markdown]
# ## PREPROCESSING FOR  DATA ANALYSIS
#
# Preprocessing analysis was carried to ensure clean format of the data cleaning task on Jupyter Notebook using preprocessing.py. Firstly, importation of pandas was configured into the Python environment to access the preprocessing cleaning setup and the .py file.

# %% [markdown]
# ### DATA QUALITY ACCESSMENT
#
# The following was checked to identify data quality issue to avoid data bias:
# * Missing Values
# * Duplicates
# * Date formats, text format, column names, and data types
# * Invalid or inconsistent records

# %%
retail_df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
retail_df.duplicated().sum()
# Out:
# 5268

# %%
netflix_df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
netflix_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### DATA CLEANING PROCESS
#
# The dataset was cleaned using the following steps:
#
# * Removal of duplicates for both dataset
# * Remove missing values
# * Standardization of data
# * Data validation
#
# NOTE: Most data cleaning processes have been carried out in the preprocessing.py file, which will be submitted along with this notebook and the preprocessing.py file details have been outlined below.

# %%
# Removal of Duplicates for Online Retail 
retail.drop_duplicates(inplace=True)

print("Duplicates Removed for Online Retail")
# Out:
# Duplicates Removed for Online Retail

# %%
# Removal of Duplicates for Netflix Titles
netflix.drop_duplicates(inplace=True)

print("Duplicates Removed for Netflix Titles")
# Out:
# Duplicates Removed for Netflix Titles

# %% [markdown]
# ### IMPORTATION OF CLEANED DATASET FROM THE PREPROCESSING.PY FILE

# %% [raw]
# import pandas as pd
#
# from preprocessing import clean_retail, clean_netflix
#
# retail = pd.read_csv("OnlineRetail.csv", encoding= "ISO-8859-1")
# netflix = pd.read_csv("netflix_titles.csv")
#
# cleaned_retail = clean_retail(retail)
# cleaned_netflix = clean_netflix(netflix)

# %%
cleaned_retail.head()

# %%
cleaned_netflix.head()

# %%
# save the cleaned retail data
cleaned_retail.to_csv("cleaned_OnlineRetail.csv", index=False)

# save the cleaned netflix data
cleaned_netflix.to_csv("cleaned_netflix_titles.csv", index=False)

# %% [markdown]
# ### DATA CLEANING SUMMARY TABLE
#
# The table below clearly shows summary of the data cleaning processes for both dataset:

# %%
invalid_count_retail = len(retail_df["Quantity"] <= 0) | (retail_df["UnitPrice"] <= 0)

# %%
summary_retail = pd.DataFrame({
    "Issue Found": [
        "Missing Values",
        "Duplicates", 
        "Invalid Entries", 
        "Standardization"
    ], 
    "count": 
    [
    retail_df.isnull().sum().sum(),
    retail_df.duplicated().sum(),
    invalid_count_retail,
    "_"
    ],     
    "Action Taken": [
           "Remove missing rows from CustomerID and Description", 
            "Removed exact duplicates", 
            "Filtered/Corrected negative values from Quantity and UnitPrice", 
            "Converted InvoiceDate to Datetime, text to uppercase"
    ]
})
                                                                                      
print("--- E-commerce Data Cleaning Summary ---")
display(summary_retail)
# Out:
# --- E-commerce Data Cleaning Summary ---
#        Issue Found                                              count  \
# 0   Missing Values                                             136534
# 1       Duplicates                                               5268
# 2  Invalid Entries  0         True
# 1         True
# 2         True
# 3...
# 3  Standardization                                                  _
#
#                                         Action Taken
# 0  Remove missing rows from CustomerID and Descri...
# 1                           Removed exact duplicates
# 2  Filtered/Corrected negative values from Quanti...
# 3  Converted InvoiceDate to Datetime, text to upp...

# %%
invalid_count_netflix = 0

# %%
import pandas as pd

# %%
summary_netflix = pd.DataFrame({
    "Issue Found": [
        "Missing Values",
        "Duplicates", 
        "Invalid Entries", 
        "Standardization"
    ], 
    "count": 
    [
    netflix_df.isnull().sum().sum(),
    netflix_df.duplicated().sum(),
    invalid_count_netflix,
    "_"
    ],     
    "Action Taken": [
           "Filled Director/Cast/Country with 'Unknown' and Removed missing dates/ratings", 
            "No action required (0)", 
            "No action required (0)",            
            "Converted date_added to Datetime"
    ]
})
                                                                                      
print("--- Netflix Titles Data Cleaning Summary ---")
display(summary_netflix)
# Out:
# --- Netflix Titles Data Cleaning Summary ---
#        Issue Found count                                       Action Taken
# 0   Missing Values  4307  Filled Director/Cast/Country with 'Unknown' an...
# 1       Duplicates     0                             No action required (0)
# 2  Invalid Entries     0                             No action required (0)
# 3  Standardization     _                   Converted date_added to Datetime

# %% [markdown]
# ## TASK 3: Exploratory Data Analysis (EDA)

# %% [markdown]
# ### EDA for E-commerce
#
# **1. Summary Statistics:**
#
# Description such as mean, median, min, max, and standard deviation will be carried out for numerical columns ('Quantity' and 'UnitPrice').
#
# **2. Exploring Data Patterns:**
#
# To analyze financial patterns, 'Revenue'('UnitPrice' * 'Quantity') column will be created to explore:
#
# * Top selling products by quantity
# * Highest revenue generating countries
# * Monthly sales trends
# * Top spending customers
# * Most purchased products by revenue

# %%
# ---1. Summary statistics ---
print("---E-commerce Summary Statistics ---")
display(cleaned_retail.describe())

# create a revenue column for generating important insights
cleaned_retail['Revenue'] = cleaned_retail['Quantity'] * cleaned_retail['UnitPrice']

# ---2. Data Patterns
print("/n1. Top 5 selling product(By Quantity):")
print(cleaned_retail.groupby('Description')['Quantity'].sum().nlargest(5))

print("/n2. Top 5 Revenue Generating Countries:")
print(cleaned_retail.groupby('Country')['Revenue'].sum().nlargest(5))

print("/n3. Top 5 Monthly Sales Trends:")

# Transforming column with coercion to be a Datetime object
cleaned_retail['InvoiceDate'] = pd.to_datetime(cleaned_retail['InvoiceDate'])

# Extract month and year for clarity
cleaned_retail['MonthYear'] = cleaned_retail['InvoiceDate'].dt.to_period('M')
print(cleaned_retail.groupby('MonthYear')['Revenue'].sum().nlargest(5))

print("/n4. Top 5 Customer by Consumer Behaviour:")
print(cleaned_retail.groupby('CustomerID')['Revenue'].sum().nlargest(5))

print("/n5. Top 5 Products by Revenue:")
print(cleaned_retail.groupby('Description')['Revenue'].sum().nlargest(5))
# Out:
# ---E-commerce Summary Statistics ---
#             Quantity      UnitPrice     CustomerID
# count  392692.000000  392692.000000  392692.000000
# mean       13.119702       3.125914   15287.843865
# std       180.492832      22.241836    1713.539549
# min         1.000000       0.001000   12346.000000
# 25%         2.000000       1.250000   13955.000000
# 50%         6.000000       1.950000   15150.000000
# 75%        12.000000       3.750000   16791.000000
# max     80995.000000    8142.750000   18287.000000
# /n1. Top 5 selling product(By Quantity):
# Description
# PAPER CRAFT , LITTLE BIRDIE           80995
# MEDIUM CERAMIC TOP STORAGE JAR        77916
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     54319
# JUMBO BAG RED RETROSPOT               46078
# WHITE HANGING HEART T-LIGHT HOLDER    36706
# Name: Quantity, dtype: int64
# /n2. Top 5 Revenue Generating Countries:
# Country
# United Kingdom    7285024.644
# Netherlands        285446.340
# EIRE               265262.460
# ...

# %% [markdown]
# **1. Summary Statistics:**
# The Netflix dataset predominantly consist of categorical(text) based data, the summary statistics will primarily apply to the 'release_year' and 'duration'(when converted to numbers).
#
# **2. Exploring Data Patterns:**
# The following distribution will be analyzed:
#
# * The ratio of Movies vs TV Shows
# * The amount of content added per year
# * The top content producing countries
# * The most common age ratings
# * The most common genres/categories

# %%
# --- 1. Summary Statistics ---
print("---Netflix Summary Statistics ---")
display(cleaned_netflix.describe())

# --- 2. Data Patterns ---
print("\n1. Movies vs TV Shows Distribution (Top 5):")
print(cleaned_netflix['type'].value_counts())

print("\n2. Top 5 years with Most Content Added:")
# Extract the year the content was added to netflix
cleaned_netflix['year_added'] = cleaned_netflix['date_added'].dt.year
print(cleaned_netflix['year_added']. value_counts().nlargest(5))

print("\n3. Top 5 Content-Producing Countries (Excluding 'Unknown'):")
print(cleaned_netflix[cleaned_netflix['country'] != 'Unknown']['country'].value_counts().nlargest(5))

print("\n4. Top 5 Common Age Ratings:")
print(cleaned_netflix['rating'].value_counts().nlargest(5))

print("\n5. Top 5 Most Common Genres/Categories:")
# Split the comma-separated genres to count individual tags

genres = cleaned_netflix['listed_in'].str.split(',').explode()
print(genres.value_counts().nlargest(5))
# Out:
# ---Netflix Summary Statistics ---
#                           date_added  release_year
# count                           8709   8709.000000
# mean   2019-05-23 01:45:29.452290816   2014.197038
# min              2008-01-01 00:00:00   1925.000000
# 25%              2018-04-20 00:00:00   2013.000000
# 50%              2019-07-12 00:00:00   2017.000000
# 75%              2020-08-26 00:00:00   2019.000000
# max              2021-09-25 00:00:00   2021.000000
# std                              NaN      8.826219
# 1. Movies vs TV Shows Distribution (Top 5):
# type
# Movie      6131
# TV Show    2578
# Name: count, dtype: int64
#
# 2. Top 5 years with Most Content Added:
# year_added
# 2019    1999
# 2020    1878
# 2018    1625
# 2021    1498
# 2017    1164
# Name: count, dtype: int64
#
# 3. Top 5 Content-Producing Countries (Excluding 'Unknown'):
# country
# United States     2778
# India              971
# United Kingdom     403
# Japan              241
# South Korea        195
# ...

# %% [markdown]
# ## TASK 4: DATA VISUALIZATION
#
# Below are 5 visualizations for exploring purchasing patterns, revenue generation, and consumer behavior for within the E-commerce dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Configure visualization styles 
sns.set_theme(style= "whitegrid") 
plt.figure(figsize=(18, 24))

# 1. Top selling products by Quantity (Bar Chart)
plt.subplot(3, 2, 1)
top_products = cleaned_retail.groupby('Description')['Quantity'].sum().nlargest(5)
sns.barplot(x=top_products.values, y=top_products.index, hue=top_products.index, palette='viridis')
plt.title('1. Top 5 selling products by Quantity')
plt.xlabel('Total Quantity Sold')
plt.ylabel('Product')

# 2. Monthly sales trends (Line Chart)
plt.subplot(3, 2, 2)
monthly_sales = cleaned_retail.groupby('MonthYear')['Revenue'].sum()
monthly_sales.astype(float).plot(kind= 'line', marker= 'o', color= 'b', linewidth=2)
plt.title('2. Monthly Sales Revenue Trend')
plt.xlabel('Month-Year')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)

# 3. Highest revenue-generating countries - Excluding UK (Bar Chart)
plt.subplot(3, 2, 3)
top_countries = cleaned_retail[cleaned_retail['Country'] != 'United Kingdom'].groupby('Country')['Revenue'].sum(
).nlargest(5)
sns.barplot(x=top_countries.values, y=top_countries.index, hue=top_countries.index, palette='magma')
plt.title('3. Top 5 Countries by Revenue')
plt.xlabel('Total Revenue (€)')
plt.ylabel('Country')

# 4. Top spenders/ Consumers Behaviors (Bar Chart)
plt.subplot(3, 2, 4)
top_customers = cleaned_retail.groupby('CustomerID')['Revenue'].sum().nlargest(5)
sns.barplot(x=top_customers.index.astype(str), y=top_customers.values, hue= top_customers.index, palette='coolwarm')
plt.title('4. Total 5 Customers by Spending')
plt.xlabel('Customer ID')
plt.ylabel('Total Revenue (€)')

# 5. Distribution pf Unit Prices under 20 (Histogram)
plt.subplot(3, 2, 5)
sns.histplot(cleaned_retail[cleaned_retail['UnitPrice'] < 20]['UnitPrice'], bins=20, color='seagreen', kde=True)
plt.title('5. Distribution of Unit Prices (Items < €20)')
plt.xlabel('Unit Price(€)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# **E-commerce Visualization Insights:**
# 1. **Top Products:** The "WORLD WAR 2 GLIDERS" and "JUMBO BAG RED RETROSPOT" are the highest volume items sold.
# 2. **Sales Trend:** Revenue steadily increases throughout the year, peaking massively in November due to holiday shopping.
# 3. **Top Countries:** While the UK is the main market, the Netherlands and EIRE (Ireland) are the highest revenue-generating international markets.
# 4. **Customer Behavior:** A few specific VIP customers (like ID 14646) spend vastly more than average, indicating strong B2B/wholesale relationships.
# 5. **Price Distribution:** The histogram shows that the vast majority of items sold are low-cost goods priced between £1 and £3.

# %% [markdown]
# ## DATA VISUALIZATION FOR NETFLIX TITLES

# %%
plt.figure(figsize=(18, 24))

# 1. Movies vs TV Shows (Pie Chart)
plt.subplot(3, 2, 1)
type_counts = cleaned_netflix['type'].value_counts()
plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', colors=['#b20710', '#221f1f'], startangle=90)
plt.title('1. Distribution of Movies vs TV Shows')

# 2. Content added by year (Line Chart)
plt.subplot(3, 2, 2)
content_by_year = cleaned_netflix['year_added'].value_counts().sort_index()
sns.lineplot(x=content_by_year.index, y=content_by_year.values, marker='o', color='#b20710', linewidth=2.5)
plt.title('2. Amount of Content Added to Netflix per Year')
plt.xlabel('Year')
plt.ylabel('Number of Titles Added')

# 3. Top content-producing countries (Bar Chart)
plt.subplot(3, 2, 3)
top_netflix_countries = cleaned_netflix[cleaned_netflix['country'] != 'Unknown']['country'].value_counts().nlargest(5)
sns.barplot(x=top_netflix_countries.values, y=top_netflix_countries.index, hue=top_netflix_countries.index, palette='Reds_r')
plt.title('3. Top 5 Content-Producing Countries')
plt.xlabel('Number of Titles')
plt.ylabel('Country')

# 4. Most common ratings (Bar Chart)
plt.subplot(3, 2, 4)
top_ratings = cleaned_netflix['rating'].value_counts().nlargest(5)
sns.barplot(x=top_ratings.index, y=top_ratings.values, hue=top_ratings.index, palette='dark:red')
plt.title('4. Top 5 Most Common Age Ratings')
plt.xlabel('Age Rating')
plt.ylabel('Count')

# 5. Most common genres/categories (Bar Chart)
plt.subplot(3, 2, 5)
genres = cleaned_netflix['listed_in'].str.split(', ').explode().value_counts().nlargest(5)
sns.barplot(x=genres.values, y=genres.index, hue=genres.index, palette='rocket')
plt.title('5. Top 5 Most Common Genres')
plt.xlabel('Number of Titles')
plt.ylabel('Genre')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## TASK 5: KEY INSIGHTS FOR EACH DATASET
#
#
# **Netflix Titles Visualization Insights:**
# 1. **Type Distribution:** Movies heavily dominate the Netflix catalog, making up roughly 70% of the content compared to TV Shows.
# 2. **Addition Trends:** Content acquisition grew exponentially starting in 2015, peaking in 2019 before slightly dipping.
# 3. **Top Countries:** The United States and India are the dominant producers of Netflix content.
# 4. **Ratings:** TV-MA (Mature Audiences) is the most common rating, showing that Netflix's primary target demographic is adults.
# 5. **Top Genres:** International Movies, Dramas, and Comedies are the most frequently listed genres on the platform.

# %% [markdown]
# **E-commerce Visualization Insights:**
# 1. **Top Products:** The "WORLD WAR 2 GLIDERS" and "JUMBO BAG RED RETROSPOT" are the highest volume items sold.
# 2. **Sales Trend:** Revenue steadily increases throughout the year, peaking massively in November due to holiday shopping.
# 3. **Top Countries:** While the UK is the main market, the Netherlands and EIRE (Ireland) are the highest revenue-generating international markets.
# 4. **Customer Behavior:** A few specific VIP customers (like ID 14646) spend vastly more than average, indicating strong B2B/wholesale relationships.
# 5. **Price Distribution:** The histogram shows that the vast majority of items sold are low-cost goods priced between £1 and £3.

# %% [markdown]
# **E-commerce Visualization Insights:**
# 1. **Top Products:** The "WORLD WAR 2 GLIDERS" and "JUMBO BAG RED RETROSPOT" are the highest volume items sold.
# 2. **Sales Trend:** Revenue steadily increases throughout the year, peaking massively in November due to holiday shopping.
# 3. **Top Countries:** While the UK is the main market, the Netherlands and EIRE (Ireland) are the highest revenue-generating international markets.
# 4. **Customer Behavior:** A few specific VIP customers (like ID 14646) spend vastly more than average, indicating strong B2B/wholesale relationships.
# 5. **Price Distribution:** The histogram shows that the vast majority of items sold are low-cost goods priced between £1 and £3.
